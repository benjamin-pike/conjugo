# %%
import os
import json
from collections import Counter

# %%
path_conjugations = os.path.join(os.pardir, 'conjugations', 'data', 'language-specific')

# %%
language = 'spanish'

# %%
with open(os.path.join(path_conjugations, f'conjugations_{language}.json'), 'r', encoding = 'utf8') as file:
    raw = json.loads(file.read())
    conjugations = {verb: raw[verb] for verb in raw if raw[verb]['rank'] <= 2000}

# %%
all_conjugations = []

for verb in conjugations:
    for complexity in ['simple', 'compound', 'progressive']:
        for mood in conjugations[verb][complexity]:
            for tense in conjugations[verb][complexity][mood]:
                for subject in ["yo", "tu", "el", "nosotros", "vosotros", "ellos"]:
                    try:
                        conjugation = conjugations[verb][complexity][mood][tense][subject]

                        all_conjugations.append( ( conjugation, [verb, complexity, mood, tense, subject] ))    
                    except KeyError:
                        pass

# %%
sorted_conjugations = sorted( list( dict( Counter( [ _[0] for _ in all_conjugations ] )).items() ), key = lambda x: x[1], reverse = True )

# %%
duplicates = [ x for x in sorted_conjugations if x[1] > 1 ]

# %%
duplicate_conjugations = []

for duplicate in duplicates:
    conjugation = duplicate[0]

    for c in all_conjugations:
        if c[0] == conjugation:
            duplicate_conjugations.append(c)

# %%
duplicate_conjugations
# Out:
# [('podamos', ['poder', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('podamos', ['poder', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('podamos', ['podar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('podamos', ['podar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('creamos', ['crear', 'simple', 'indicative', 'present', 'nosotros']),
#  ('creamos', ['crear', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('creamos', ['creer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('creamos', ['creer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('vengamos', ['venir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('vengamos', ['venir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('vengamos', ['vengar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('vengamos', ['vengar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('fundamos', ['fundar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('fundamos', ['fundar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('fundamos', ['fundir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('fundamos', ['fundir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('paramos', ['parar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('paramos', ['parar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('paramos', ['parir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('paramos', ['parir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('devengamos', ['devenir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('devengamos',
#   ['devenir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('devengamos', ['devengar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('devengamos', ['devengar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('consumamos', ['consumir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('consumamos',
#   ['consumir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('consumamos', ['consumar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('consumamos', ['consumar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('molamos', ['moler', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('molamos', ['moler', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('molamos', ['molar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('molamos', ['molar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('podemos', ['poder', 'simple', 'indicative', 'present', 'nosotros']),
#  ('podemos', ['podar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('podemos', ['podar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('creemos', ['crear', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('creemos', ['crear', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('creemos', ['creer', 'simple', 'indicative', 'present', 'nosotros']),
#  ('molemos', ['moler', 'simple', 'indicative', 'present', 'nosotros']),
#  ('molemos', ['molar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('molemos', ['molar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('equiparemos',
#   ['equiparar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('equiparemos',
#   ['equiparar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('equiparemos', ['equipar', 'simple', 'indicative', 'future', 'nosotros']),
#  ('fui', ['ser', 'simple', 'indicative', 'preterite', 'yo']),
#  ('fui', ['ir', 'simple', 'indicative', 'preterite', 'yo']),
#  ('fuimos', ['ser', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('fuimos', ['ir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('fuisteis', ['ser', 'simple', 'indicative', 'preterite', 'vosotros']),
#  ('fuisteis', ['ir', 'simple', 'indicative', 'preterite', 'vosotros']),
#  ('fueron', ['ser', 'simple', 'indicative', 'preterite', 'ellos']),
#  ('fueron', ['ir', 'simple', 'indicative', 'preterite', 'ellos']),
#  ('seamos', ['ser', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('seamos', ['ser', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('fuera', ['ser', 'simple', 'subjunctive', 'imperfect', 'yo']),
#  ('fuera', ['ir', 'simple', 'subjunctive', 'imperfect', 'yo']),
#  ('fuéramos', ['ser', 'simple', 'subjunctive', 'imperfect', 'nosotros']),
#  ('fuéramos', ['ir', 'simple', 'subjunctive', 'imperfect', 'nosotros']),
#  ('fuerais', ['ser', 'simple', 'subjunctive', 'imperfect', 'vosotros']),
#  ('fuerais', ['ir', 'simple', 'subjunctive', 'imperfect', 'vosotros']),
#  ('fueran', ['ser', 'simple', 'subjunctive', 'imperfect', 'ellos']),
#  ('fueran', ['ir', 'simple', 'subjunctive', 'imperfect', 'ellos']),
#  ('fuere', ['ser', 'simple', 'subjunctive', 'future', 'yo']),
#  ('fuere', ['ir', 'simple', 'subjunctive', 'future', 'yo']),
#  ('fuéremos', ['ser', 'simple', 'subjunctive', 'future', 'nosotros']),
#  ('fuéremos', ['ir', 'simple', 'subjunctive', 'future', 'nosotros']),
#  ('fuereis', ['ser', 'simple', 'subjunctive', 'future', 'vosotros']),
#  ('fuereis', ['ir', 'simple', 'subjunctive', 'future', 'vosotros']),
#  ('fueren', ['ser', 'simple', 'subjunctive', 'future', 'ellos']),
#  ('fueren', ['ir', 'simple', 'subjunctive', 'future', 'ellos']),
#  ('hagamos', ['hacer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('hagamos', ['hacer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('digamos', ['decir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('digamos', ['decir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('podéis', ['poder', 'simple', 'indicative', 'present', 'vosotros']),
#  ('podéis', ['podar', 'simple', 'subjunctive', 'present', 'vosotros']),
#  ('podáis', ['poder', 'simple', 'subjunctive', 'present', 'vosotros']),
#  ('podáis', ['podar', 'simple', 'indicative', 'present', 'vosotros']),
#  ('tengamos', ['tener', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('tengamos', ['tener', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('veamos', ['ver', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('veamos', ['ver', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('partimos', ['partir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('partimos', ['partir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('partamos', ['partir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('partamos', ['partir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('hayamos', ['haber', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('hayamos', ['haber', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('demos', ['dar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('demos', ['dar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('estemos', ['estar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('estemos', ['estar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('debamos', ['deber', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('debamos', ['deber', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('sepamos', ['saber', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('sepamos', ['saber', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('llegamos', ['llegar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('llegamos', ['llegar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('lleguemos', ['llegar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('lleguemos', ['llegar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('hablamos', ['hablar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('hablamos', ['hablar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('hablemos', ['hablar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('hablemos', ['hablar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('conozcamos', ['conocer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('conozcamos',
#   ['conocer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('vamos', ['ir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('vamos', ['ir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('tomamos', ['tomar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('tomamos', ['tomar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('tomemos', ['tomar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('tomemos', ['tomar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('realizamos', ['realizar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('realizamos', ['realizar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('realicemos', ['realizar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('realicemos',
#   ['realizar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('pensamos', ['pensar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('pensamos', ['pensar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('pensemos', ['pensar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('pensemos', ['pensar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('establezcamos',
#   ['establecer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('establezcamos',
#   ['establecer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('seguimos', ['seguir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('seguimos', ['seguir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('sigamos', ['seguir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('sigamos', ['seguir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('pasamos', ['pasar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('pasamos', ['pasar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('pasemos', ['pasar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('pasemos', ['pasar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('evitamos', ['evitar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('evitamos', ['evitar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('evitemos', ['evitar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('evitemos', ['evitar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('pongamos', ['poner', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('pongamos', ['poner', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('vivimos', ['vivir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('vivimos', ['vivir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('vivamos', ['vivir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('vivamos', ['vivir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('llevamos', ['llevar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('llevamos', ['llevar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('llevemos', ['llevar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('llevemos', ['llevar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('obtengamos', ['obtener', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('obtengamos',
#   ['obtener', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('dejamos', ['dejar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('dejamos', ['dejar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('dejemos', ['dejar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('dejemos', ['dejar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('mantengamos', ['mantener', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('mantengamos',
#   ['mantener', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('logramos', ['lograr', 'simple', 'indicative', 'present', 'nosotros']),
#  ('logramos', ['lograr', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('logremos', ['lograr', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('logremos', ['lograr', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('encontramos', ['encontrar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('encontramos',
#   ['encontrar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('encontremos',
#   ['encontrar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('encontremos',
#   ['encontrar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('salimos', ['salir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('salimos', ['salir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('salen', ['salir', 'simple', 'indicative', 'present', 'ellos']),
#  ('salen', ['salar', 'simple', 'subjunctive', 'present', 'ellos']),
#  ('salgamos', ['salir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('salgamos', ['salir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('creo', ['crear', 'simple', 'indicative', 'present', 'yo']),
#  ('creo', ['creer', 'simple', 'indicative', 'present', 'yo']),
#  ('creáis', ['crear', 'simple', 'indicative', 'present', 'vosotros']),
#  ('creáis', ['creer', 'simple', 'subjunctive', 'present', 'vosotros']),
#  ('crean', ['crear', 'simple', 'indicative', 'present', 'ellos']),
#  ('crean', ['creer', 'simple', 'subjunctive', 'present', 'ellos']),
#  ('creéis', ['crear', 'simple', 'subjunctive', 'present', 'vosotros']),
#  ('creéis', ['creer', 'simple', 'indicative', 'present', 'vosotros']),
#  ('creen', ['crear', 'simple', 'subjunctive', 'present', 'ellos']),
#  ('creen', ['creer', 'simple', 'indicative', 'present', 'ellos']),
#  ('entendamos', ['entender', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('entendamos',
#   ['entender', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('consideramos',
#   ['considerar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('consideramos',
#   ['considerar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('consideremos',
#   ['considerar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('consideremos',
#   ['considerar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('cumplimos', ['cumplir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('cumplimos', ['cumplir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('cumplamos', ['cumplir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('cumplamos', ['cumplir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('trabajamos', ['trabajar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('trabajamos', ['trabajar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('trabajemos', ['trabajar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('trabajemos',
#   ['trabajar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('buscamos', ['buscar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('buscamos', ['buscar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('busquemos', ['buscar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('busquemos', ['buscar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('escribimos', ['escribir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('escribimos', ['escribir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('escribamos', ['escribir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('escribamos',
#   ['escribir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('entramos', ['entrar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('entramos', ['entrar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('entremos', ['entrar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('entremos', ['entrar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('señalamos', ['señalar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('señalamos', ['señalar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('señalemos', ['señalar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('señalemos', ['señalar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('alcanzamos', ['alcanzar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('alcanzamos', ['alcanzar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('alcancemos', ['alcanzar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('alcancemos',
#   ['alcanzar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('pagamos', ['pagar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('pagamos', ['pagar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('paguemos', ['pagar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('paguemos', ['pagar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('contamos', ['contar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('contamos', ['contar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('contemos', ['contar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('contemos', ['contar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('volvamos', ['volver', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('volvamos', ['volver', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('tratamos', ['tratar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('tratamos', ['tratar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('tratemos', ['tratar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('tratemos', ['tratar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('resolvamos', ['resolver', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('resolvamos',
#   ['resolver', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('determinamos',
#   ['determinar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('determinamos',
#   ['determinar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('determinemos',
#   ['determinar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('determinemos',
#   ['determinar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('recibimos', ['recibir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('recibimos', ['recibir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('recibamos', ['recibir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('recibamos', ['recibir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('comprendamos',
#   ['comprender', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('comprendamos',
#   ['comprender', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('parezcamos', ['parecer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('parezcamos',
#   ['parecer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('presentamos', ['presentar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('presentamos',
#   ['presentar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('presentemos',
#   ['presentar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('presentemos',
#   ['presentar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('mejoramos', ['mejorar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('mejoramos', ['mejorar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('mejoremos', ['mejorar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('mejoremos', ['mejorar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('leamos', ['leer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('leamos', ['leer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('desarrollamos',
#   ['desarrollar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('desarrollamos',
#   ['desarrollar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('desarrollemos',
#   ['desarrollar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('desarrollemos',
#   ['desarrollar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('formamos', ['formar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('formamos', ['formar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('formemos', ['formar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('formemos', ['formar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('produzcamos', ['producir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('produzcamos',
#   ['producir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('esperamos', ['esperar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('esperamos', ['esperar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('esperemos', ['esperar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('esperemos', ['esperar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('abrimos', ['abrir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('abrimos', ['abrir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('abramos', ['abrir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('abramos', ['abrir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('reconozcamos',
#   ['reconocer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('reconozcamos',
#   ['reconocer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('recordamos', ['recordar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('recordamos', ['recordar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('recordemos', ['recordar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('recordemos',
#   ['recordar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('conseguimos', ['conseguir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('conseguimos',
#   ['conseguir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('consigamos', ['conseguir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('consigamos',
#   ['conseguir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('construimos', ['construir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('construimos',
#   ['construir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('construyamos',
#   ['construir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('construyamos',
#   ['construir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('explicamos', ['explicar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('explicamos', ['explicar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('expliquemos', ['explicar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('expliquemos',
#   ['explicar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('observamos', ['observar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('observamos', ['observar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('observemos', ['observar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('observemos',
#   ['observar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('estudiamos', ['estudiar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('estudiamos', ['estudiar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('estudiemos', ['estudiar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('estudiemos',
#   ['estudiar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('participamos',
#   ['participar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('participamos',
#   ['participar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('participemos',
#   ['participar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('participemos',
#   ['participar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('servimos', ['servir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('servimos', ['servir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('sirvamos', ['servir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('sirvamos', ['servir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('analizamos', ['analizar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('analizamos', ['analizar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('analicemos', ['analizar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('analicemos',
#   ['analizar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('aseguramos', ['asegurar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('aseguramos', ['asegurar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('aseguremos', ['asegurar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('aseguremos',
#   ['asegurar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('aceptamos', ['aceptar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('aceptamos', ['aceptar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('aceptemos', ['aceptar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('aceptemos', ['aceptar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('cambiamos', ['cambiar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('cambiamos', ['cambiar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('cambiemos', ['cambiar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('cambiemos', ['cambiar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('utilizamos', ['utilizar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('utilizamos', ['utilizar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('utilicemos', ['utilizar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('utilicemos',
#   ['utilizar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('perdamos', ['perder', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('perdamos', ['perder', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('destacamos', ['destacar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('destacamos', ['destacar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('destaquemos', ['destacar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('destaquemos',
#   ['destacar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('siento', ['sentir', 'simple', 'indicative', 'present', 'yo']),
#  ('siento', ['sentar', 'simple', 'indicative', 'present', 'yo']),
#  ('sentimos', ['sentir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('sentimos', ['sentir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('sienten', ['sentir', 'simple', 'indicative', 'present', 'ellos']),
#  ('sienten', ['sentar', 'simple', 'subjunctive', 'present', 'ellos']),
#  ('sintamos', ['sentir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('sintamos', ['sentir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('sientan', ['sentir', 'simple', 'subjunctive', 'present', 'ellos']),
#  ('sientan', ['sentar', 'simple', 'indicative', 'present', 'ellos']),
#  ('morimos', ['morir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('morimos', ['morir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('muramos', ['morir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('muramos', ['morir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('pesamos', ['pesar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('pesamos', ['pesar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('pesemos', ['pesar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('pesemos', ['pesar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('reduzcamos', ['reducir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('reduzcamos',
#   ['reducir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('afirmamos', ['afirmar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('afirmamos', ['afirmar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('afirmemos', ['afirmar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('afirmemos', ['afirmar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('actuamos', ['actuar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('actuamos', ['actuar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('actuemos', ['actuar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('actuemos', ['actuar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('comamos', ['comer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('comamos', ['comer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('aumentamos', ['aumentar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('aumentamos', ['aumentar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('aumentemos', ['aumentar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('aumentemos',
#   ['aumentar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('caigamos', ['caer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('caigamos', ['caer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('continuamos', ['continuar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('continuamos',
#   ['continuar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('continuemos',
#   ['continuar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('continuemos',
#   ['continuar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('llamamos', ['llamar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('llamamos', ['llamar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('llamemos', ['llamar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('llamemos', ['llamar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('promovamos', ['promover', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('promovamos',
#   ['promover', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('terminamos', ['terminar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('terminamos', ['terminar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('terminemos', ['terminar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('terminemos',
#   ['terminar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('andemos', ['andar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('andemos', ['andar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('definimos', ['definir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('definimos', ['definir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('definamos', ['definir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('definamos', ['definir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('aplicamos', ['aplicar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('aplicamos', ['aplicar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('apliquemos', ['aplicar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('apliquemos',
#   ['aplicar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('existimos', ['existir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('existimos', ['existir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('existamos', ['existir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('existamos', ['existir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('sacamos', ['sacar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('sacamos', ['sacar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('saquemos', ['sacar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('saquemos', ['sacar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('defendamos', ['defender', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('defendamos',
#   ['defender', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('vengo', ['venir', 'simple', 'indicative', 'present', 'yo']),
#  ('vengo', ['vengar', 'simple', 'indicative', 'present', 'yo']),
#  ('vengáis', ['venir', 'simple', 'subjunctive', 'present', 'vosotros']),
#  ('vengáis', ['vengar', 'simple', 'indicative', 'present', 'vosotros']),
#  ('vengan', ['venir', 'simple', 'subjunctive', 'present', 'ellos']),
#  ('vengan', ['vengar', 'simple', 'indicative', 'present', 'ellos']),
#  ('ofrezcamos', ['ofrecer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('ofrezcamos',
#   ['ofrecer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('respondamos',
#   ['responder', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('respondamos',
#   ['responder', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('ejerzamos', ['ejercer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('ejerzamos', ['ejercer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('atendamos', ['atender', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('atendamos', ['atender', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('quedamos', ['quedar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('quedamos', ['quedar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('quedemos', ['quedar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('quedemos', ['quedar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('garantizamos',
#   ['garantizar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('garantizamos',
#   ['garantizar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('garanticemos',
#   ['garantizar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('garanticemos',
#   ['garantizar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('olvidamos', ['olvidar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('olvidamos', ['olvidar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('olvidemos', ['olvidar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('olvidemos', ['olvidar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('pedimos', ['pedir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('pedimos', ['pedir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('pidamos', ['pedir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('pidamos', ['pedir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('mostramos', ['mostrar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('mostramos', ['mostrar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('mostremos', ['mostrar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('mostremos', ['mostrar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('expresamos', ['expresar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('expresamos', ['expresar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('expresemos', ['expresar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('expresemos',
#   ['expresar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('superamos', ['superar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('superamos', ['superar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('superemos', ['superar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('superemos', ['superar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('usamos', ['usar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('usamos', ['usar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('usemos', ['usar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('usemos', ['usar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('asumimos', ['asumir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('asumimos', ['asumir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('asumamos', ['asumir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('asumamos', ['asumir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('adquirimos', ['adquirir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('adquirimos', ['adquirir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('adquiramos', ['adquirir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('adquiramos',
#   ['adquirir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('cubrimos', ['cubrir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('cubrimos', ['cubrir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('cubramos', ['cubrir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('cubramos', ['cubrir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('satisfagamos',
#   ['satisfacer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('satisfagamos',
#   ['satisfacer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('concluimos', ['concluir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('concluimos', ['concluir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('concluyamos', ['concluir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('concluyamos',
#   ['concluir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('demostramos', ['demostrar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('demostramos',
#   ['demostrar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('demostremos',
#   ['demostrar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('demostremos',
#   ['demostrar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('descubrimos', ['descubrir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('descubrimos',
#   ['descubrir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('descubramos',
#   ['descubrir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('descubramos',
#   ['descubrir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('permitimos', ['permitir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('permitimos', ['permitir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('permitamos', ['permitir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('permitamos',
#   ['permitir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('miramos', ['mirar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('miramos', ['mirar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('miremos', ['mirar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('miremos', ['mirar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('contribuimos',
#   ['contribuir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('contribuimos',
#   ['contribuir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('contribuyamos',
#   ['contribuir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('contribuyamos',
#   ['contribuir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('compramos', ['comprar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('compramos', ['comprar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('compremos', ['comprar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('compremos', ['comprar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('mencionamos', ['mencionar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('mencionamos',
#   ['mencionar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('mencionemos',
#   ['mencionar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('mencionemos',
#   ['mencionar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('ayudamos', ['ayudar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('ayudamos', ['ayudar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('ayudemos', ['ayudar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('ayudemos', ['ayudar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('controlamos', ['controlar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('controlamos',
#   ['controlar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('controlemos',
#   ['controlar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('controlemos',
#   ['controlar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('identificamos',
#   ['identificar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('identificamos',
#   ['identificar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('identifiquemos',
#   ['identificar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('identifiquemos',
#   ['identificar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('aprendamos', ['aprender', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('aprendamos',
#   ['aprender', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('generamos', ['generar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('generamos', ['generar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('generemos', ['generar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('generemos', ['generar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('constituimos',
#   ['constituir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('constituimos',
#   ['constituir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('constituyamos',
#   ['constituir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('constituyamos',
#   ['constituir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('supongamos', ['suponer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('supongamos',
#   ['suponer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('facilitamos', ['facilitar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('facilitamos',
#   ['facilitar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('facilitemos',
#   ['facilitar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('facilitemos',
#   ['facilitar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('queramos', ['querer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('queramos', ['querer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('ganamos', ['ganar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('ganamos', ['ganar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('ganemos', ['ganar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('ganemos', ['ganar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('distinguimos',
#   ['distinguir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('distinguimos',
#   ['distinguir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('distingamos',
#   ['distinguir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('distingamos',
#   ['distinguir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('vendamos', ['vender', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('vendamos', ['vender', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('organizamos', ['organizar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('organizamos',
#   ['organizar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('organicemos',
#   ['organizar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('organicemos',
#   ['organizar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('iniciamos', ['iniciar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('iniciamos', ['iniciar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('iniciemos', ['iniciar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('iniciemos', ['iniciar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('dispongamos', ['disponer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('dispongamos',
#   ['disponer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('efectuamos', ['efectuar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('efectuamos', ['efectuar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('efectuemos', ['efectuar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('efectuemos',
#   ['efectuar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('escuchamos', ['escuchar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('escuchamos', ['escuchar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('escuchemos', ['escuchar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('escuchemos',
#   ['escuchar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('enfrentamos', ['enfrentar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('enfrentamos',
#   ['enfrentar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('enfrentemos',
#   ['enfrentar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('enfrentemos',
#   ['enfrentar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('impedimos', ['impedir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('impedimos', ['impedir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('impidamos', ['impedir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('impidamos', ['impedir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('incluimos', ['incluir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('incluimos', ['incluir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('incluyamos', ['incluir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('incluyamos',
#   ['incluir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('adoptamos', ['adoptar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('adoptamos', ['adoptar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('adoptemos', ['adoptar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('adoptemos', ['adoptar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('procedamos', ['proceder', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('procedamos',
#   ['proceder', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('abandonamos', ['abandonar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('abandonamos',
#   ['abandonar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('abandonemos',
#   ['abandonar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('abandonemos',
#   ['abandonar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('ocupamos', ['ocupar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('ocupamos', ['ocupar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('ocupemos', ['ocupar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('ocupemos', ['ocupar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('aparezcamos', ['aparecer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('aparezcamos',
#   ['aparecer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('elegimos', ['elegir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('elegimos', ['elegir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('elijamos', ['elegir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('elijamos', ['elegir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('representamos',
#   ['representar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('representamos',
#   ['representar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('representemos',
#   ['representar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('representemos',
#   ['representar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('impongamos', ['imponer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('impongamos',
#   ['imponer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('sostengamos', ['sostener', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('sostengamos',
#   ['sostener', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('conservamos', ['conservar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('conservamos',
#   ['conservar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('conservemos',
#   ['conservar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('conservemos',
#   ['conservar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('protejamos', ['proteger', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('protejamos',
#   ['proteger', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('apoyamos', ['apoyar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('apoyamos', ['apoyar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('apoyemos', ['apoyar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('apoyemos', ['apoyar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('evaluamos', ['evaluar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('evaluamos', ['evaluar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('evaluemos', ['evaluar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('evaluemos', ['evaluar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('comprobamos', ['comprobar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('comprobamos',
#   ['comprobar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('comprobemos',
#   ['comprobar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('comprobemos',
#   ['comprobar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('apreciamos', ['apreciar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('apreciamos', ['apreciar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('apreciemos', ['apreciar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('apreciemos',
#   ['apreciar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('indicamos', ['indicar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('indicamos', ['indicar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('indiquemos', ['indicar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('indiquemos',
#   ['indicar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('comenzamos', ['comenzar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('comenzamos', ['comenzar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('comencemos', ['comenzar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('comencemos',
#   ['comenzar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('corramos', ['correr', 'simple', 'subjunctive', 'present', 'nosotros']),
# ...
#  ('traigamos', ['traer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('celebramos', ['celebrar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('celebramos', ['celebrar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('celebremos', ['celebrar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('celebremos',
#   ['celebrar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('propongamos', ['proponer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('propongamos',
#   ['proponer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('negamos', ['negar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('negamos', ['negar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('neguemos', ['negar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('neguemos', ['negar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('resultamos', ['resultar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('resultamos', ['resultar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('resultemos', ['resultar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('resultemos',
#   ['resultar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('exigimos', ['exigir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('exigimos', ['exigir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('exijamos', ['exigir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('exijamos', ['exigir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('planteamos', ['plantear', 'simple', 'indicative', 'present', 'nosotros']),
#  ('planteamos', ['plantear', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('planteemos', ['plantear', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('planteemos',
#   ['plantear', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('discutimos', ['discutir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('discutimos', ['discutir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('discutamos', ['discutir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('discutamos',
#   ['discutir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('aclaramos', ['aclarar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('aclaramos', ['aclarar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('aclaremos', ['aclarar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('aclaremos', ['aclarar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('crezcamos', ['crecer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('crezcamos', ['crecer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('dirigimos', ['dirigir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('dirigimos', ['dirigir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('dirijamos', ['dirigir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('dirijamos', ['dirigir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('cantamos', ['cantar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('cantamos', ['cantar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('cantemos', ['cantar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('cantemos', ['cantar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('conduzcamos', ['conducir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('conduzcamos',
#   ['conducir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('medimos', ['medir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('medimos', ['medir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('midamos', ['medir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('midamos', ['medir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('admitimos', ['admitir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('admitimos', ['admitir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('admitamos', ['admitir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('admitamos', ['admitir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('compartimos', ['compartir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('compartimos',
#   ['compartir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('compartamos',
#   ['compartir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('compartamos',
#   ['compartir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('guardamos', ['guardar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('guardamos', ['guardar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('guardemos', ['guardar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('guardemos', ['guardar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('tocamos', ['tocar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('tocamos', ['tocar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('toquemos', ['tocar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('toquemos', ['tocar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('probamos', ['probar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('probamos', ['probar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('probemos', ['probar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('probemos', ['probar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('convertimos', ['convertir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('convertimos',
#   ['convertir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('convirtamos',
#   ['convertir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('convirtamos',
#   ['convertir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('contengamos', ['contener', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('contengamos',
#   ['contener', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('formulamos', ['formular', 'simple', 'indicative', 'present', 'nosotros']),
#  ('formulamos', ['formular', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('formulemos', ['formular', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('formulemos',
#   ['formular', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('cerramos', ['cerrar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('cerramos', ['cerrar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('cerremos', ['cerrar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('cerremos', ['cerrar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('impulsamos', ['impulsar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('impulsamos', ['impulsar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('impulsemos', ['impulsar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('impulsemos',
#   ['impulsar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('asistimos', ['asistir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('asistimos', ['asistir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('asistamos', ['asistir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('asistamos', ['asistir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('elevamos', ['elevar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('elevamos', ['elevar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('elevemos', ['elevar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('elevemos', ['elevar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('percibimos', ['percibir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('percibimos', ['percibir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('percibamos', ['percibir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('percibamos',
#   ['percibir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('desaparezcamos',
#   ['desaparecer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('desaparezcamos',
#   ['desaparecer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('advertimos', ['advertir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('advertimos', ['advertir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('advirtamos', ['advertir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('advirtamos',
#   ['advertir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('integramos', ['integrar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('integramos', ['integrar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('integremos', ['integrar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('integremos',
#   ['integrar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('caminamos', ['caminar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('caminamos', ['caminar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('caminemos', ['caminar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('caminemos', ['caminar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('incorporamos',
#   ['incorporar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('incorporamos',
#   ['incorporar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('incorporemos',
#   ['incorporar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('incorporemos',
#   ['incorporar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('acudimos', ['acudir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('acudimos', ['acudir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('acudamos', ['acudir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('acudamos', ['acudir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('precisamos', ['precisar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('precisamos', ['precisar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('precisemos', ['precisar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('precisemos',
#   ['precisar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('fomentamos', ['fomentar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('fomentamos', ['fomentar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('fomentemos', ['fomentar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('fomentemos',
#   ['fomentar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('enviamos', ['enviar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('enviamos', ['enviar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('enviemos', ['enviar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('enviemos', ['enviar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('destruimos', ['destruir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('destruimos', ['destruir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('destruyamos', ['destruir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('destruyamos',
#   ['destruir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('nazcamos', ['nacer', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('nazcamos', ['nacer', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('provocamos', ['provocar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('provocamos', ['provocar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('provoquemos', ['provocar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('provoquemos',
#   ['provocar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('subimos', ['subir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('subimos', ['subir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('subamos', ['subir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('subamos', ['subir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('ejecutamos', ['ejecutar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('ejecutamos', ['ejecutar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('ejecutemos', ['ejecutar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('ejecutemos',
#   ['ejecutar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('colocamos', ['colocar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('colocamos', ['colocar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('coloquemos', ['colocar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('coloquemos',
#   ['colocar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('reunimos', ['reunir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('reunimos', ['reunir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('reunamos', ['reunir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('reunamos', ['reunir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('otorgamos', ['otorgar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('otorgamos', ['otorgar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('otorguemos', ['otorgar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('otorguemos',
#   ['otorgar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('respetamos', ['respetar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('respetamos', ['respetar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('respetemos', ['respetar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('respetemos',
#   ['respetar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('despertamos', ['despertar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('despertamos',
#   ['despertar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('despertemos',
#   ['despertar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('despertemos',
#   ['despertar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('imaginamos', ['imaginar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('imaginamos', ['imaginar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('imaginemos', ['imaginar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('imaginemos',
#   ['imaginar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('visitamos', ['visitar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('visitamos', ['visitar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('visitemos', ['visitar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('visitemos', ['visitar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('cobramos', ['cobrar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('cobramos', ['cobrar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('cobremos', ['cobrar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('cobremos', ['cobrar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('bajamos', ['bajar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('bajamos', ['bajar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('bajemos', ['bajar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('bajemos', ['bajar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('votamos', ['votar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('votamos', ['votar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('votemos', ['votar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('votemos', ['votar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('agregamos', ['agregar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('agregamos', ['agregar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('agreguemos', ['agregar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('agreguemos',
#   ['agregar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('repetimos', ['repetir', 'simple', 'indicative', 'present', 'nosotros']),
#  ('repetimos', ['repetir', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('repitamos', ['repetir', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('repitamos', ['repetir', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('informamos', ['informar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('informamos', ['informar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ('informemos', ['informar', 'simple', 'subjunctive', 'present', 'nosotros']),
#  ('informemos',
#   ['informar', 'simple', 'imperative', 'affirmative', 'nosotros']),
#  ('completamos', ['completar', 'simple', 'indicative', 'present', 'nosotros']),
#  ('completamos',
#   ['completar', 'simple', 'indicative', 'preterite', 'nosotros']),
#  ...]

# %%
len(all_conjugations)
# Out:
# 234153

# %%
conjugations.keys()
# Out:
# dict_keys(['ser', 'hacer', 'decir', 'poder', 'tener', 'ver', 'partir', 'haber', 'dar', 'estar', 'deber', 'saber', 'llegar', 'hablar', 'conocer', 'ir', 'tomar', 'realizar', 'pensar', 'establecer', 'seguir', 'pasar', 'evitar', 'poner', 'vivir', 'llevar', 'obtener', 'dejar', 'mantener', 'lograr', 'encontrar', 'salir', 'crear', 'entender', 'considerar', 'cumplir', 'trabajar', 'buscar', 'escribir', 'entrar', 'señalar', 'alcanzar', 'pagar', 'contar', 'volver', 'tratar', 'resolver', 'determinar', 'recibir', 'comprender', 'parecer', 'presentar', 'mejorar', 'leer', 'desarrollar', 'formar', 'producir', 'esperar', 'abrir', 'reconocer', 'recordar', 'conseguir', 'construir', 'explicar', 'observar', 'estudiar', 'participar', 'servir', 'analizar', 'asegurar', 'aceptar', 'cambiar', 'utilizar', 'perder', 'destacar', 'sentir', 'morir', 'pesar', 'reducir', 'afirmar', 'actuar', 'comer', 'aumentar', 'caer', 'continuar', 'llamar', 'promover', 'terminar', 'creer', 'andar', 'definir', 'aplicar', 'existir', 'sacar', 'defender', 'venir', 'ofrecer', 'responder', 'ejercer', 'atender', 'quedar', 'garantizar', 'olvidar', 'pedir', 'mostrar', 'expresar', 'superar', 'usar', 'asumir', 'adquirir', 'cubrir', 'satisfacer', 'concluir', 'demostrar', 'descubrir', 'permitir', 'mirar', 'contribuir', 'comprar', 'mencionar', 'ayudar', 'controlar', 'identificar', 'aprender', 'generar', 'constituir', 'suponer', 'facilitar', 'querer', 'ganar', 'distinguir', 'vender', 'organizar', 'iniciar', 'disponer', 'efectuar', 'escuchar', 'enfrentar', 'impedir', 'incluir', 'adoptar', 'proceder', 'abandonar', 'ocupar', 'aparecer', 'elegir', 'representar', 'imponer', 'sostener', 'conservar', 'proteger', 'apoyar', 'evaluar', 'comprobar', 'apreciar', 'indicar', 'comenzar', 'correr', 'modificar', 'recuperar', 'empezar', 'intentar', 'ampliar', 'eliminar', 'oír', 'notar', 'regresar', 'dormir', 'decidir', 'jugar', 'introducir', 'elaborar', 'citar', 'recurrir', 'examinar', 'matar', 'solicitar', 'fijar', 'aprovechar', 'luchar', 'romper', 'acceder', 'preparar', 'fortalecer', 'añadir', 'sufrir', 'recoger', 'combatir', 'circular', 'declarar', 'incrementar', 'avanzar', 'prestar', 'intervenir', 'interpretar', 'salvar', 'disminuir', 'justificar', 'permanecer', 'describir', 'acabar', 'entregar', 'levantar', 'juzgar', 'proporcionar', 'publicar', 'traer', 'celebrar', 'proponer', 'negar', 'resultar', 'exigir', 'plantear', 'discutir', 'aclarar', 'crecer', 'dirigir', 'cantar', 'conducir', 'medir', 'admitir', 'compartir', 'guardar', 'tocar', 'probar', 'convertir', 'contener', 'formular', 'cerrar', 'impulsar', 'asistir', 'elevar', 'percibir', 'desaparecer', 'advertir', 'integrar', 'caminar', 'incorporar', 'acudir', 'precisar', 'fomentar', 'enviar', 'destruir', 'nacer', 'provocar', 'subir', 'ejecutar', 'colocar', 'reunir', 'otorgar', 'respetar', 'despertar', 'imaginar', 'visitar', 'cobrar', 'bajar', 'votar', 'agregar', 'repetir', 'informar', 'completar', 'nombrar', 'abordar', 'echar', 'consolidar', 'escapar', 'revisar', 'hallar', 'poseer', 'transformar', 'enseñar', 'financiar', 'operar', 'desempeñar', 'emprender', 'llorar', 'manejar', 'renunciar', 'emplear', 'exponer', 'corregir', 'funcionar', 'investigar', 'vencer', 'contemplar', 'favorecer', 'afectar', 'ordenar', 'fundar', 'estimular', 'negociar', 'comparar', 'finalizar', 'llenar', 'beber', 'reforzar', 'proveer', 'significar', 'resaltar', 'mandar', 'soportar', 'captar', 'surgir', 'solucionar', 'detener', 'designar', 'recorrer', 'amar', 'preservar', 'sobrevivir', 'gozar', 'consultar', 'prevenir', 'insistir', 'sustituir', 'constar', 'profundizar', 'aportar', 'gobernar', 'afrontar', 'huir', 'parar', 'viajar', 'contestar', 'dictar', 'extender', 'preguntar', 'ingresar', 'manifestar', 'influir', 'rechazar', 'conceder', 'invertir', 'pretender', 'cortar', 'valorar', 'competir', 'vestir', 'disfrutar', 'calcular', 'concebir', 'confirmar', 'atacar', 'deducir', 'reflexionar', 'administrar', 'penetrar', 'resistir', 'verificar', 'dominar', 'subrayar', 'limitar', 'practica ...
